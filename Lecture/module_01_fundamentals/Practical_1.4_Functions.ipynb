# %% [markdown]
# # Practical lecture 0.3 — Functions
#
# Python for (Open) Neuroscience
#
# ## Practical outline
#
# - Writing simple functions
# - Arguments and default values
# - Return values
# - Functions that work on strings and lists
# - Side effects and in-place modification
# - Functions calling other functions
# - `map()`, `filter()`, and `lambda`
# - Functions as objects
#
# Use the empty cells below each exercise to write your solution.

# %% [markdown]
# ## 0.3.1 Functions part 1
#
# ### Question 1
#
# Keep in mind that if a function has both non-default and default arguments, all default arguments must come **after** the non-default ones in the function header.
#
# Which function header is **incorrect**?
#
# ```python
# def func(a, b, c=1)
#
# def func(a=1, b, c=1)
#
# def func(a=1, b=1, c=1)
#
# def func(a, b, c)
# ```

# %%
# Write your answer here

# %% [markdown]
# ## Exercise 1
#
# Write a function called `is_even` that takes a number as input and returns `True` if the number is even, and `False` otherwise.

# %%
def is_even(n):
    return ____

print(is_even(4))
print(is_even(7))

# %% [markdown]
# ## Exercise 2
#
# Write a function called `is_odd` that takes a number as input and returns `True` if the number is odd, and `False` otherwise.

# %%
def is_odd(n):
    return ____

print(is_odd(4))
print(is_odd(7))

# %% [markdown]
# ## Exercise 3
#
# Write a function called `square_number` that takes one input value and returns its square.

# %%
def square_number(x):
    return ____

print(square_number(5))

# %% [markdown]
# ## Exercise 4
#
# Write a function called `cube_number` that takes one input value and returns its cube.

# %%
def cube_number(x):
    return ____

print(cube_number(3))

# %% [markdown]
# ## Exercise 5
#
# Write a function called `list_average` that takes a list of numbers and returns its mean.

# %%
def list_average(values):
    return ____

values = [2, 4, 6, 8]
print(list_average(values))

# %% [markdown]
# ## Exercise 6
#
# Write a function that takes a string as input and returns the number of words in that string.
#
# Hint: use `.split()`.

# %%
def count_words(text):
    return len(____)

sentence = "Neuroscience and Python work very well together"
print(count_words(sentence))

# %% [markdown]
# ## Exercise 7
#
# Write a function that takes a string as input and returns a list in which all words longer than 6 characters are replaced with `"###"`.

# %%
def redact_words(input_string):
    words = ____.split()
    output_words = []

    for word in ____:
        if len(word) > ____:
            output_words.append("###")
        else:
            output_words.append(____)

    return ____

example_input = "Neuroscience students usually enjoy computational methods"
print(redact_words(example_input))

# %% [markdown]
# ## Exercise 8
#
# Modify the previous function so that the threshold is an argument with default value `6`.

# %%
def redact_words(input_string, threshold=6):
    words = ____.split()
    output_words = []

    for word in ____:
        if len(word) > ____:
            output_words.append("###")
        else:
            output_words.append(____)

    return ____

example_input = "Neuroscience students usually enjoy computational methods"
print(redact_words(example_input))
print(redact_words(example_input, threshold=8))

# %% [markdown]
# ## Exercise 9
#
# Write a function called `exponentiate` that takes two arguments, `a` and `b`, and returns `a ** b`.
#
# Then call it with positional arguments and with keyword arguments.

# %%
def exponentiate(a, b):
    return ____

print(exponentiate(2, 3))
print(exponentiate(a=2, b=3))

# %% [markdown]
# ## Exercise 10
#
# Write a function called `greet_participant` with one required argument `name` and one default argument `group="control"`.
#
# The function should return a string like `"Participant Sara belongs to group control"`.

# %%
def greet_participant(name, group="control"):
    return ____

print(greet_participant("Sara"))
print(greet_participant("Luca", group="treatment"))

# %% [markdown]
# ## Exercise 11
#
# Write a function called `min_and_max` that takes a list of numbers and returns two values: the minimum and the maximum.

# %%
def min_and_max(numbers):
    return ____, ____

values = [4, 9, 1, 7, 3]
smallest, largest = min_and_max(values)
print(smallest)
print(largest)

# %% [markdown]
# ## Exercise 12
#
# Functions always return something, even if we do not write `return`.
#
# Complete the function below, run it, and observe what gets printed. What is the value of `result`?

# %%
def print_message():
    print("Hello from the function")

result = print_message()
print(result)

# %% [markdown]
# ## Exercise 13
#
# By just reading the code below, predict the issue. Then fix the function so that it does not modify the input list in place.

# %%
list_of_vals = [1, 2, 3]

def multiply_values(numbers, coeff=2):
    """Multiply all values in a list by a coefficient"""
    for i in range(len(numbers)):
        numbers[i] = numbers[i] * coeff
    return numbers

print(list_of_vals)
double_vals = multiply_values(list_of_vals, 2)
print(double_vals, list_of_vals)
triple_vals = multiply_values(list_of_vals, 3)
print(triple_vals, list_of_vals)

# Rewrite the function below:
def multiply_values_fixed(numbers, coeff=2):
    new_numbers = ____
    for value in ____:
        new_numbers.append(____)
    return ____

# %% [markdown]
# ## Exercise 14
#
# Write a function called `calc_distance` that takes two points `(x1, y1)` and `(x2, y2)` and returns the Euclidean distance between them.

# %%
def calc_distance(point1, point2):
    x1, y1 = ____
    x2, y2 = ____
    return ____

print(calc_distance((0, 0), (3, 4)))

# %% [markdown]
# ## Exercise 15
#
# Write a function called `calc_perimeter` that takes a list of polygon coordinates and returns the perimeter. Use your `calc_distance()` function inside it.

# %%
def calc_distance(point1, point2):
    x1, y1 = point1
    x2, y2 = point2
    return ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5

def calc_perimeter(coordinates):
    perimeter = ____
    for i in range(____):
        perimeter += calc_distance(____, ____)
    return ____

square_coordinates = [(0, 0), (1, 0), (1, 1), (0, 1), (0, 0)]
print(calc_perimeter(square_coordinates))

# %% [markdown]
# ## Exercise 16
#
# Write a function that computes the population variance of a list.

# %%
def variance(numbers):
    mean_value = ____
    squared_diffs = [(x - mean_value) ** 2 for x in ____]
    return ____

participants_height = [167, 185, 179, 191, 178, 180, 175, 188, 170]
height_var = variance(participants_height)
print(height_var)

# %% [markdown]
# ## Exercise 17
#
# Update the previous function by adding a `df` argument for degrees of freedom. Set the default value to `1`, so that by default the function computes the sample variance.

# %%
def variance(numbers, df=1):
    mean_value = ____
    squared_diffs = [(x - mean_value) ** 2 for x in ____]
    return ____

participants_height = [167, 185, 179, 191, 178, 180, 175, 188, 170]
print(variance(participants_height))
print(variance(participants_height, df=0))

# %% [markdown]
# ## Exercise 18
#
# Write three functions: `calc_mean(numbers)`, `calc_std(numbers, mean=None)`, and `z_score(numbers)`.
#
# The `z_score()` function should return the z-scored version of the input list.

# %%
data_list = [2.1, 1.3, 4.0, 0.5, 2.7, 3.1]

def calc_mean(numbers):
    return ____

def calc_std(numbers, mean=None):
    if mean is None:
        mean = ____
    variance = sum((x - mean) ** 2 for x in numbers) / (len(numbers) - 1)
    return ____

def z_score(numbers):
    mean_value = ____
    std_value = ____
    return [____ for x in numbers]

print(z_score(data_list))

# %% [markdown]
# ## `map()`, `filter()`, and `lambda`

# %% [markdown]
# ## Exercise 19
#
# Use `map()` to convert a list of integers into a list of strings.

# %%
numbers = [1, 2, 3, 4]
result = map(____, numbers)
print(list(result))

# %% [markdown]
# ## Exercise 20
#
# You performed a learning task and got accuracy values for 10 subjects stored in a dictionary. Save the IDs of the participants whose score is above `0.6` in a separate list, using `filter()` and `lambda`.

# %%
accuracy_scores = {
    'id1': 0.27, 'id2': 0.75, 'id3': 0.61, 'id4': 0.05, 'id5': 0.40,
    'id6': 0.67, 'id7': 0.69, 'id8': 0.52, 'id9': 0.70, 'id10': 0.30
}

good_ids = list(filter(____, accuracy_scores.items()))
print(good_ids)

# %% [markdown]
# ## Exercise 21
#
# Your experiment had 5 subjects in a control group and 5 subjects in a treatment group. However, the labels were written in an inconsistent way.
#
# 1. Clean the `groups` list so that the values become only `'control'` and `'treatment'` using `map()` and `lambda`
# 2. Then use a `for` loop and an `if` statement to separate IDs into two lists

# %%
ids = [
    'id1', 'id2', 'id3', 'id4', 'id5',
    'id6', 'id7', 'id8', 'id9', 'id10'
]

groups = [
    'ContrOl_1', 'ContrOl_1', 'TreatMent_2', 'ContrOl_1', 'TreatMent_2',
    'TreatMent_2', 'TreatMent_2', 'TreatMent_2', 'ContrOl_1', 'ContrOl_1'
]

groups_cleaned = [____ for group in ____]

ids_ctl = ____
ids_trt = ____

for i in range(len(ids)):
    if ____:
        ids_ctl.append(____)
    else:
        ids_trt.append(____)

print(f"Control Group: {ids_ctl}")
print(f"Treatment Group: {ids_trt}")

# %% [markdown]
# ## Functions as objects

# %% [markdown]
# ## Exercise 22
#
# Store two functions inside a dictionary and call them through the dictionary.

# %%
def multiply_numbers(x, y):
    return x * y

def add_numbers(x, y):
    return x + y

function_dict = {
    'multiply': ____,
    'add': ____
}

print(function_dict['multiply'](3, 4))
print(function_dict['add'](3, 4))

# %% [markdown]
# ## Exercise 23
#
# Create a simple preprocessing pipeline. Store the functions in a list, then write `apply_pipeline(data, functions)` to apply all steps in order.

# %%
raw_data = [5, -3, 2, -1, 9, 4, -2, 0, 7]

def step_one_remove_negatives(numbers):
    return [max(0, num) for num in numbers]

def step_two_square_values(numbers):
    return [num ** 2 for num in numbers]

def step_three_normalize(numbers):
    max_val = max(numbers) if numbers else 1
    return [num / max_val for num in numbers]

preprocessing_steps = [____, ____, ____]

def apply_pipeline(data, functions):
    result = ____
    for func in ____:
        result = ____
    return ____

processed_data = apply_pipeline(raw_data, preprocessing_steps)
print(processed_data)

# %% [markdown]
# ## Optional challenge questions
#
# ### Challenge 1
# Write a function `count_above_threshold(numbers, threshold=0)` that returns how many values are strictly greater than `threshold`.
#
# ### Challenge 2
# Write a function `first_long_word(text, threshold=6)` that returns the **first** word longer than `threshold`. If no such word exists, return `None`.
#
# ### Challenge 3
# Write a function `apply_twice(func, x)` that applies a function two times to the same input.

# %%
# Optional: write your solutions here
